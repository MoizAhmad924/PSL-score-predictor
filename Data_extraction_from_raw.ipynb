# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data\\1075986.yaml',
#  'data\\1075987.yaml',
#  'data\\1075988.yaml',
#  'data\\1075989.yaml',
#  'data\\1075990.yaml']

# %%
final_df = pd.DataFrame()
counter = 1

for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = pd.concat([final_df, df], ignore_index=True)
        counter += 1

final_df
# Out:
#  99%|█████████▉| 146/147 [00:36<00:00,  4.01it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[22], line 6
#       4 for file in tqdm(filenames):
#       5     with open(file, 'r') as f:
# ----> 6         df = pd.json_normalize(safe_load(f))
#       7         df['match_id'] = counter
#       8         final_df = pd.concat([final_df, df], ignore_index=True)
#
# File c:\Users\ENIAC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)
#     455     and max_level is None
#     456 ):
#
# NotImplementedError:

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                                innings  meta.data_version  \
# 0    [{'1st innings': {'team': 'Peshawar Zalmi', 'd...                0.9
# 1    [{'1st innings': {'team': 'Quetta Gladiators',...                0.9
# 2    [{'1st innings': {'team': 'Karachi Kings', 'de...                0.9
# 3    [{'1st innings': {'team': 'Islamabad United', ...                0.9
# 4    [{'1st innings': {'team': 'Karachi Kings', 'de...                0.9
# ..                                                 ...                ...
# 141  [{'1st innings': {'team': 'Lahore Qalandars', ...                0.9
# 142  [{'1st innings': {'team': 'Quetta Gladiators',...                0.9
# 143  [{'1st innings': {'team': 'Karachi Kings', 'de...                0.9
# 144  [{'1st innings': {'team': 'Islamabad United', ...                0.9
# 145  [{'1st innings': {'team': 'Quetta Gladiators',...                0.9
#
#     meta.created  meta.revision       info.competition    info.dates  \
# 0     2017-05-04              1  Pakistan Super League  [2017-02-09]
# 1     2017-05-06              2  Pakistan Super League  [2017-02-10]
# 2     2017-05-05              1  Pakistan Super League  [2017-02-10]
# 3     2017-05-06              1  Pakistan Super League  [2017-02-11]
# 4     2017-05-05              2  Pakistan Super League  [2017-02-11]
# ..           ...            ...                    ...           ...
# 141   2020-08-17              1  Pakistan Super League  [2016-02-17]
# 142   2020-08-17              1  Pakistan Super League  [2016-02-19]
# 143   2020-08-17              1  Pakistan Super League  [2016-02-20]
# 144   2020-08-17              1  Pakistan Super League  [2016-02-21]
# 145   2020-08-17              1  Pakistan Super League  [2016-02-23]
#
#     info.gender info.match_type  info.neutral_venue  info.outcome.by.wickets  \
# 0          male             T20                 1.0                      7.0
# 1          male             T20                 1.0                      NaN
# 2          male             T20                 1.0                      7.0
# 3          male             T20                 1.0                      6.0
# 4          male             T20                 1.0                      7.0
# ..          ...             ...                 ...                      ...
# 141        male             T20                 NaN                      5.0
# 142        male             T20                 NaN                      NaN
# 143        male             T20                 NaN                      9.0
# 144        male             T20                 NaN                      NaN
# 145        male             T20                 NaN                      6.0
#
#      ...                             info.teams info.toss.decision  \
# 0    ...     [Islamabad United, Peshawar Zalmi]              field
# 1    ...  [Lahore Qalandars, Quetta Gladiators]              field
# 2    ...        [Karachi Kings, Peshawar Zalmi]              field
# 3    ...   [Islamabad United, Lahore Qalandars]              field
# 4    ...     [Karachi Kings, Quetta Gladiators]              field
# ..   ...                                    ...                ...
# 141  ...   [Lahore Qalandars, Islamabad United]              field
# 142  ...    [Quetta Gladiators, Peshawar Zalmi]              field
# 143  ...      [Karachi Kings, Islamabad United]              field
# 144  ...     [Islamabad United, Peshawar Zalmi]              field
# 145  ...  [Quetta Gladiators, Islamabad United]              field
#
#       info.toss.winner                info.umpires  \
# 0     Islamabad United   [Ahsan Raza, Shozab Raza]
# 1     Lahore Qalandars  [Rashid Riaz, Shozab Raza]
# 2       Peshawar Zalmi  [Ahmed Shahab, Ahsan Raza]
# 3     Lahore Qalandars  [Asif Yaqoob, Shozab Raza]
# 4    Quetta Gladiators    [Aleem Dar, Rashid Riaz]
# ..                 ...                         ...
# 141   Islamabad United      [JS Wilson, Aleem Dar]
# 142     Peshawar Zalmi    [Shozab Raza, Aleem Dar]
# 143   Islamabad United     [Aleem Dar, Ahsan Raza]
# 144     Peshawar Zalmi      [JS Wilson, Aleem Dar]
# 145   Islamabad United      [JS Wilson, Aleem Dar]
#
#                               info.venue match_id info.outcome.by.runs  \
# 0    Dubai International Cricket Stadium        1                  NaN
# 1    Dubai International Cricket Stadium        2                  8.0
# 2    Dubai International Cricket Stadium        3                  NaN
# 3    Dubai International Cricket Stadium        4                  NaN
# 4    Dubai International Cricket Stadium        5                  NaN
# ..                                   ...      ...                  ...
# 141  Dubai International Cricket Stadium      142                  NaN
# 142  Dubai International Cricket Stadium      143                  1.0
# 143  Dubai International Cricket Stadium      144                  NaN
# 144  Dubai International Cricket Stadium      145                 50.0
# 145  Dubai International Cricket Stadium      146                  NaN
#
#     info.outcome.result info.city  info.outcome.eliminator
# 0                   NaN       NaN                      NaN
# 1                   NaN       NaN                      NaN
# 2                   NaN       NaN                      NaN
# 3                   NaN       NaN                      NaN
# 4                   NaN       NaN                      NaN
# ..                  ...       ...                      ...
# 141                 NaN       NaN                      NaN
# 142                 NaN       NaN                      NaN
# 143                 NaN       NaN                      NaN
# 144                 NaN       NaN                      NaN
# 145                 NaN       NaN                      NaN
#
# [146 rows x 24 columns]

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                                innings       info.competition  \
# 0    [{'1st innings': {'team': 'Peshawar Zalmi', 'd...  Pakistan Super League
# 1    [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
# 2    [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# 3    [{'1st innings': {'team': 'Islamabad United', ...  Pakistan Super League
# 4    [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# ..                                                 ...                    ...
# 141  [{'1st innings': {'team': 'Lahore Qalandars', ...  Pakistan Super League
# 142  [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
# 143  [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# 144  [{'1st innings': {'team': 'Islamabad United', ...  Pakistan Super League
# 145  [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
#
#        info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# 0    [2017-02-09]        male             T20    Islamabad United          20
# 1    [2017-02-10]        male             T20   Quetta Gladiators          20
# 2    [2017-02-10]        male             T20      Peshawar Zalmi          20
# 3    [2017-02-11]        male             T20    Lahore Qalandars          20
# 4    [2017-02-11]        male             T20   Quetta Gladiators          20
# ..            ...         ...             ...                 ...         ...
# 141  [2016-02-17]        male             T20    Islamabad United          20
# 142  [2016-02-19]        male             T20   Quetta Gladiators          20
# 143  [2016-02-20]        male             T20    Islamabad United          20
# 144  [2016-02-21]        male             T20    Islamabad United          20
# 145  [2016-02-23]        male             T20    Islamabad United          20
#
#      info.player_of_match                             info.teams  \
# 0             [BJ Haddin]     [Islamabad United, Peshawar Zalmi]
# 1           [Hassan Khan]  [Lahore Qalandars, Quetta Gladiators]
# 2            [EJG Morgan]        [Karachi Kings, Peshawar Zalmi]
# 3                [JJ Roy]   [Islamabad United, Lahore Qalandars]
# 4            [RR Rossouw]     [Karachi Kings, Quetta Gladiators]
# ..                    ...                                    ...
# 141      [Mohammad Irfan]   [Lahore Qalandars, Islamabad United]
# 142  [Mohammad Nawaz (3)]    [Quetta Gladiators, Peshawar Zalmi]
# 143       [Mohammad Sami]      [Karachi Kings, Islamabad United]
# 144       [Sharjeel Khan]     [Islamabad United, Peshawar Zalmi]
# 145            [DR Smith]  [Quetta Gladiators, Islamabad United]
#
#     info.toss.decision   info.toss.winner                info.umpires  \
# 0                field   Islamabad United   [Ahsan Raza, Shozab Raza]
# 1                field   Lahore Qalandars  [Rashid Riaz, Shozab Raza]
# 2                field     Peshawar Zalmi  [Ahmed Shahab, Ahsan Raza]
# 3                field   Lahore Qalandars  [Asif Yaqoob, Shozab Raza]
# 4                field  Quetta Gladiators    [Aleem Dar, Rashid Riaz]
# ..                 ...                ...                         ...
# 141              field   Islamabad United      [JS Wilson, Aleem Dar]
# 142              field     Peshawar Zalmi    [Shozab Raza, Aleem Dar]
# 143              field   Islamabad United     [Aleem Dar, Ahsan Raza]
# 144              field     Peshawar Zalmi      [JS Wilson, Aleem Dar]
# 145              field   Islamabad United      [JS Wilson, Aleem Dar]
#
#                               info.venue  match_id info.city
# 0    Dubai International Cricket Stadium         1       NaN
# 1    Dubai International Cricket Stadium         2       NaN
# 2    Dubai International Cricket Stadium         3       NaN
# 3    Dubai International Cricket Stadium         4       NaN
# 4    Dubai International Cricket Stadium         5       NaN
# ..                                   ...       ...       ...
# 141  Dubai International Cricket Stadium       142       NaN
# 142  Dubai International Cricket Stadium       143       NaN
# 143  Dubai International Cricket Stadium       144       NaN
# 144  Dubai International Cricket Stadium       145       NaN
# 145  Dubai International Cricket Stadium       146       NaN
#
# [146 rows x 15 columns]

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male    146
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
#                                                innings       info.competition  \
# 0    [{'1st innings': {'team': 'Peshawar Zalmi', 'd...  Pakistan Super League
# 1    [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
# 2    [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# 3    [{'1st innings': {'team': 'Islamabad United', ...  Pakistan Super League
# 4    [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# ..                                                 ...                    ...
# 141  [{'1st innings': {'team': 'Lahore Qalandars', ...  Pakistan Super League
# 142  [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
# 143  [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# 144  [{'1st innings': {'team': 'Islamabad United', ...  Pakistan Super League
# 145  [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
#
#        info.dates info.match_type info.outcome.winner  info.overs  \
# 0    [2017-02-09]             T20    Islamabad United          20
# 1    [2017-02-10]             T20   Quetta Gladiators          20
# 2    [2017-02-10]             T20      Peshawar Zalmi          20
# 3    [2017-02-11]             T20    Lahore Qalandars          20
# 4    [2017-02-11]             T20   Quetta Gladiators          20
# ..            ...             ...                 ...         ...
# 141  [2016-02-17]             T20    Islamabad United          20
# 142  [2016-02-19]             T20   Quetta Gladiators          20
# 143  [2016-02-20]             T20    Islamabad United          20
# 144  [2016-02-21]             T20    Islamabad United          20
# 145  [2016-02-23]             T20    Islamabad United          20
#
#      info.player_of_match                             info.teams  \
# 0             [BJ Haddin]     [Islamabad United, Peshawar Zalmi]
# 1           [Hassan Khan]  [Lahore Qalandars, Quetta Gladiators]
# 2            [EJG Morgan]        [Karachi Kings, Peshawar Zalmi]
# 3                [JJ Roy]   [Islamabad United, Lahore Qalandars]
# 4            [RR Rossouw]     [Karachi Kings, Quetta Gladiators]
# ..                    ...                                    ...
# 141      [Mohammad Irfan]   [Lahore Qalandars, Islamabad United]
# 142  [Mohammad Nawaz (3)]    [Quetta Gladiators, Peshawar Zalmi]
# 143       [Mohammad Sami]      [Karachi Kings, Islamabad United]
# 144       [Sharjeel Khan]     [Islamabad United, Peshawar Zalmi]
# 145            [DR Smith]  [Quetta Gladiators, Islamabad United]
#
#     info.toss.decision   info.toss.winner                info.umpires  \
# 0                field   Islamabad United   [Ahsan Raza, Shozab Raza]
# 1                field   Lahore Qalandars  [Rashid Riaz, Shozab Raza]
# 2                field     Peshawar Zalmi  [Ahmed Shahab, Ahsan Raza]
# 3                field   Lahore Qalandars  [Asif Yaqoob, Shozab Raza]
# 4                field  Quetta Gladiators    [Aleem Dar, Rashid Riaz]
# ..                 ...                ...                         ...
# 141              field   Islamabad United      [JS Wilson, Aleem Dar]
# 142              field     Peshawar Zalmi    [Shozab Raza, Aleem Dar]
# 143              field   Islamabad United     [Aleem Dar, Ahsan Raza]
# 144              field     Peshawar Zalmi      [JS Wilson, Aleem Dar]
# 145              field   Islamabad United      [JS Wilson, Aleem Dar]
#
#                               info.venue  match_id info.city
# 0    Dubai International Cricket Stadium         1       NaN
# 1    Dubai International Cricket Stadium         2       NaN
# 2    Dubai International Cricket Stadium         3       NaN
# 3    Dubai International Cricket Stadium         4       NaN
# 4    Dubai International Cricket Stadium         5       NaN
# ..                                   ...       ...       ...
# 141  Dubai International Cricket Stadium       142       NaN
# 142  Dubai International Cricket Stadium       143       NaN
# 143  Dubai International Cricket Stadium       144       NaN
# 144  Dubai International Cricket Stadium       145       NaN
# 145  Dubai International Cricket Stadium       146       NaN
#
# [146 rows x 14 columns]

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    146
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    146
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type','info.competition'],inplace=True)
final_df
# Out:
#                                                innings    info.dates  \
# 0    [{'1st innings': {'team': 'Peshawar Zalmi', 'd...  [2017-02-09]
# 1    [{'1st innings': {'team': 'Quetta Gladiators',...  [2017-02-10]
# 2    [{'1st innings': {'team': 'Karachi Kings', 'de...  [2017-02-10]
# 3    [{'1st innings': {'team': 'Islamabad United', ...  [2017-02-11]
# 4    [{'1st innings': {'team': 'Karachi Kings', 'de...  [2017-02-11]
# ..                                                 ...           ...
# 141  [{'1st innings': {'team': 'Lahore Qalandars', ...  [2016-02-17]
# 142  [{'1st innings': {'team': 'Quetta Gladiators',...  [2016-02-19]
# 143  [{'1st innings': {'team': 'Karachi Kings', 'de...  [2016-02-20]
# 144  [{'1st innings': {'team': 'Islamabad United', ...  [2016-02-21]
# 145  [{'1st innings': {'team': 'Quetta Gladiators',...  [2016-02-23]
#
#     info.outcome.winner  info.player_of_match  \
# 0      Islamabad United           [BJ Haddin]
# 1     Quetta Gladiators         [Hassan Khan]
# 2        Peshawar Zalmi          [EJG Morgan]
# 3      Lahore Qalandars              [JJ Roy]
# 4     Quetta Gladiators          [RR Rossouw]
# ..                  ...                   ...
# 141    Islamabad United      [Mohammad Irfan]
# 142   Quetta Gladiators  [Mohammad Nawaz (3)]
# 143    Islamabad United       [Mohammad Sami]
# 144    Islamabad United       [Sharjeel Khan]
# 145    Islamabad United            [DR Smith]
#
#                                 info.teams info.toss.decision  \
# 0       [Islamabad United, Peshawar Zalmi]              field
# 1    [Lahore Qalandars, Quetta Gladiators]              field
# 2          [Karachi Kings, Peshawar Zalmi]              field
# 3     [Islamabad United, Lahore Qalandars]              field
# 4       [Karachi Kings, Quetta Gladiators]              field
# ..                                     ...                ...
# 141   [Lahore Qalandars, Islamabad United]              field
# 142    [Quetta Gladiators, Peshawar Zalmi]              field
# 143      [Karachi Kings, Islamabad United]              field
# 144     [Islamabad United, Peshawar Zalmi]              field
# 145  [Quetta Gladiators, Islamabad United]              field
#
#       info.toss.winner                info.umpires  \
# 0     Islamabad United   [Ahsan Raza, Shozab Raza]
# 1     Lahore Qalandars  [Rashid Riaz, Shozab Raza]
# 2       Peshawar Zalmi  [Ahmed Shahab, Ahsan Raza]
# 3     Lahore Qalandars  [Asif Yaqoob, Shozab Raza]
# 4    Quetta Gladiators    [Aleem Dar, Rashid Riaz]
# ..                 ...                         ...
# 141   Islamabad United      [JS Wilson, Aleem Dar]
# 142     Peshawar Zalmi    [Shozab Raza, Aleem Dar]
# 143   Islamabad United     [Aleem Dar, Ahsan Raza]
# 144     Peshawar Zalmi      [JS Wilson, Aleem Dar]
# 145   Islamabad United      [JS Wilson, Aleem Dar]
#
#                               info.venue  match_id info.city
# 0    Dubai International Cricket Stadium         1       NaN
# 1    Dubai International Cricket Stadium         2       NaN
# 2    Dubai International Cricket Stadium         3       NaN
# 3    Dubai International Cricket Stadium         4       NaN
# 4    Dubai International Cricket Stadium         5       NaN
# ..                                   ...       ...       ...
# 141  Dubai International Cricket Stadium       142       NaN
# 142  Dubai International Cricket Stadium       143       NaN
# 143  Dubai International Cricket Stadium       144       NaN
# 144  Dubai International Cricket Stadium       145       NaN
# 145  Dubai International Cricket Stadium       146       NaN
#
# [146 rows x 11 columns]

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
#matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'Mohammad Hafeez',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Sharjeel Khan'],
#     'kind': 'caught',
#     'player_out': 'Mohammad Hafeez'}}},
#  {0.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.3: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.4: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {1.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'extras': {'legbyes': 1},
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {1.5: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {1.6: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {2.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {2.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {2.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.3: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'extras': {'legbyes': 1},
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {3.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {3.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.6: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {4.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.3: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {4.4: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.5: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {4.6: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'extras': {'legbyes': 1},
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {5.3: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'extras': {'legbyes': 4},
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 4, 'total': 4}}},
#  {5.4: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.5: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {6.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {6.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.5: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.3: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {7.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.6: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.2: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.3: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {8.4: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {9.1: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.3: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.4: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {9.5: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {10.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {10.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.4: {'batsman': 'DJ Malan',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {10.5: {'batsman': 'DJ Malan',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {11.1: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {11.2: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.3: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Imran Khalid'],
#     'kind': 'caught',
#     'player_out': 'DJ Malan'}}},
#  {11.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'EJG Morgan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.5: {'batsman': 'EJG Morgan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'EJG Morgan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'EJG Morgan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.2: {'batsman': 'EJG Morgan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.3: {'batsman': 'EJG Morgan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'EJG Morgan'}}},
#  {12.4: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.1: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.3: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.4: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.5: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.1: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {14.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {14.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.1: {'batsman': 'Haris Sohail',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.2: {'batsman': 'Haris Sohail',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Misbah-ul-Haq'],
#     'kind': 'caught',
#     'player_out': 'Kamran Akmal'}}},
#  {15.4: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.5: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.6: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.1: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.2: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {16.3: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.4: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Sharjeel Khan'],
#     'kind': 'caught',
#     'player_out': 'DJG Sammy'}}},
#  {16.5: {'batsman': 'Shahid Afridi',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Mohammad Irfan',
#    'extras': {'byes': 4},
#    'non_striker': 'Shahid Afridi',
#    'runs': {'batsman': 0, 'extras': 4, 'total': 4}}},
#  {17.1: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {17.2: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.3: {'batsman': 'Haris Sohail',
#    'bowler': 'SR Watson',
#    'non_striker': 'Shahid Afridi',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.4: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {17.5: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Misbah-ul-Haq'],
#     'kind': 'caught',
#     'player_out': 'Shahid Afridi'}}},
#  {17.6: {'batsman': 'Haris Sohail',
#    'bowler': 'SR Watson',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['BJ Haddin'],
#     'kind': 'caught',
#     'player_out': 'Haris Sohail'}}},
#  {17.7: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.1: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.2: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.3: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.4: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.5: {'batsman': 'Iftikhar Ahmed',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['BJ Haddin'],
#     'kind': 'caught',
#     'player_out': 'Iftikhar Ahmed'}}},
#  {18.6: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Hasan Ali',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.1: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Hasan Ali',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {19.2: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Hasan Ali',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.3: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {19.4: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {19.5: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {19.6: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {19.7: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Amad Butt'],
#     'kind': 'caught',
#     'player_out': 'Hasan Ali'}}},
#  {19.8: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Junaid Khan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {19.9: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Junaid Khan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}]

# %%
count = 1
match_dfs = []
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    match_dfs.append(loop_df)

delivery_df = pd.concat(match_dfs, ignore_index=True)

# %%
delivery_df
# Out:
#        match_id                                  teams       batting_team  \
# 0             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 1             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 2             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 3             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 4             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# ...         ...                                    ...                ...
# 17322       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17323       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17324       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17325       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17326       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
#
#        ball          batsman          bowler  runs player_dismissed city  \
# 0       0.1  Mohammad Hafeez  Mohammad Irfan     0  Mohammad Hafeez  NaN
# 1       0.2     Kamran Akmal  Mohammad Irfan     1                0  NaN
# 2       0.3         DJ Malan  Mohammad Irfan     0                0  NaN
# 3       0.4         DJ Malan  Mohammad Irfan     0                0  NaN
# 4       0.5         DJ Malan  Mohammad Irfan     0                0  NaN
# ...     ...              ...             ...   ...              ...  ...
# 17322  19.2        Anwar Ali      AD Russell     6                0  NaN
# 17323  19.3        Anwar Ali      AD Russell     2                0  NaN
# 17324  19.4        Anwar Ali      AD Russell     0        Anwar Ali  NaN
# 17325  19.5       GD Elliott      AD Russell     0                0  NaN
# 17326  19.6       GD Elliott      AD Russell     6                0  NaN
#
#                                      venue
# 0      Dubai International Cricket Stadium
# 1      Dubai International Cricket Stadium
# 2      Dubai International Cricket Stadium
# 3      Dubai International Cricket Stadium
# 4      Dubai International Cricket Stadium
# ...                                    ...
# 17322  Dubai International Cricket Stadium
# 17323  Dubai International Cricket Stadium
# 17324  Dubai International Cricket Stadium
# 17325  Dubai International Cricket Stadium
# 17326  Dubai International Cricket Stadium
#
# [17327 rows x 10 columns]

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#        match_id                                  teams       batting_team  \
# 0             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 1             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 2             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 3             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 4             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# ...         ...                                    ...                ...
# 17322       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17323       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17324       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17325       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 17326       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
#
#        ball          batsman          bowler  runs player_dismissed city  \
# 0       0.1  Mohammad Hafeez  Mohammad Irfan     0  Mohammad Hafeez  NaN
# 1       0.2     Kamran Akmal  Mohammad Irfan     1                0  NaN
# 2       0.3         DJ Malan  Mohammad Irfan     0                0  NaN
# 3       0.4         DJ Malan  Mohammad Irfan     0                0  NaN
# 4       0.5         DJ Malan  Mohammad Irfan     0                0  NaN
# ...     ...              ...             ...   ...              ...  ...
# 17322  19.2        Anwar Ali      AD Russell     6                0  NaN
# 17323  19.3        Anwar Ali      AD Russell     2                0  NaN
# 17324  19.4        Anwar Ali      AD Russell     0        Anwar Ali  NaN
# 17325  19.5       GD Elliott      AD Russell     0                0  NaN
# 17326  19.6       GD Elliott      AD Russell     6                0  NaN
#
#                                      venue      bowling_team
# 0      Dubai International Cricket Stadium  Islamabad United
# 1      Dubai International Cricket Stadium  Islamabad United
# 2      Dubai International Cricket Stadium  Islamabad United
# 3      Dubai International Cricket Stadium  Islamabad United
# 4      Dubai International Cricket Stadium  Islamabad United
# ...                                    ...               ...
# 17322  Dubai International Cricket Stadium  Islamabad United
# 17323  Dubai International Cricket Stadium  Islamabad United
# 17324  Dubai International Cricket Stadium  Islamabad United
# 17325  Dubai International Cricket Stadium  Islamabad United
# 17326  Dubai International Cricket Stadium  Islamabad United
#
# [17327 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Peshawar Zalmi', 'Quetta Gladiators', 'Karachi Kings',
#        'Islamabad United', 'Lahore Qalandars', 'Multan Sultans'],
#       dtype=object)

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#        match_id       batting_team      bowling_team  ball  runs  \
# 0             2     Peshawar Zalmi  Islamabad United   0.1     0
# 1             2     Peshawar Zalmi  Islamabad United   0.2     1
# 2             2     Peshawar Zalmi  Islamabad United   0.3     0
# 3             2     Peshawar Zalmi  Islamabad United   0.4     0
# 4             2     Peshawar Zalmi  Islamabad United   0.5     0
# ...         ...                ...               ...   ...   ...
# 17322       147  Quetta Gladiators  Islamabad United  19.2     6
# 17323       147  Quetta Gladiators  Islamabad United  19.3     2
# 17324       147  Quetta Gladiators  Islamabad United  19.4     0
# 17325       147  Quetta Gladiators  Islamabad United  19.5     0
# 17326       147  Quetta Gladiators  Islamabad United  19.6     6
#
#       player_dismissed city                                venue
# 0      Mohammad Hafeez  NaN  Dubai International Cricket Stadium
# 1                    0  NaN  Dubai International Cricket Stadium
# 2                    0  NaN  Dubai International Cricket Stadium
# 3                    0  NaN  Dubai International Cricket Stadium
# 4                    0  NaN  Dubai International Cricket Stadium
# ...                ...  ...                                  ...
# 17322                0  NaN  Dubai International Cricket Stadium
# 17323                0  NaN  Dubai International Cricket Stadium
# 17324        Anwar Ali  NaN  Dubai International Cricket Stadium
# 17325                0  NaN  Dubai International Cricket Stadium
# 17326                0  NaN  Dubai International Cricket Stadium
#
# [17327 rows x 8 columns]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
output[output['city'].isnull()]['venue'].value_counts()

# %%
x = np.where(output['city'].isnull(), output['venue'].str.split().apply(lambda x:x[0]), output['city'])

# %%
output['city'] = x

# %%
output.isnull().sum()

# %%
output.drop(columns=['venue'],inplace=True)

# %%
output

# %%
total_df = output.groupby('match_id').sum()['runs'].reset_index()
output = output.merge(total_df,on='match_id')

# %%
output

# %%
output['current_score'] = output.groupby('match_id').cumsum()['runs_x']

# %%
output['over'] = output['ball'].apply(lambda x:str(x).split(".")[0])
output['ball_no'] = output['ball'].apply(lambda x:str(x).split(".")[1])

# %%
output['balls_bowled'] = (output['over'].astype('int')*6) + output['ball_no'].astype('int')

# %%
output['crr'] = round((output['current_score']*6)/output['balls_bowled'],2)

# %%
output['player_dismissed'] = output['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
output['player_dismissed'] = output['player_dismissed'].astype('int')
output['player_dismissed'] = output.groupby('match_id').cumsum()['player_dismissed']
output['wickets_left'] = 10 - output['player_dismissed']

# %%
final_df = output[['match_id','batting_team','bowling_team','runs_x','current_score','balls_bowled','wickets_left','crr','city','runs_y']]

# %%
final_df

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df['balls_left'] = 120 - final_df['balls_bowled']
final_df['balls_left'] = final_df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
final_df['crr'] = round((final_df['current_score']*6)/final_df['balls_bowled'],2)

# %%
final_df

# %%
final_df.drop(columns=['balls_bowled'],inplace=True)

# %%
groups = final_df.groupby('match_id')

# %%
match_ids = final_df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs_x'].values.tolist())

# %%
final_df['last_five'] = last_five

# %%
final_df

# %%
final_df.dropna(inplace=True)

# %%
final_df

# %%
eligible_cities = final_df['city'].value_counts()[final_df['city'].value_counts() > 600].index.tolist()
final_df = final_df[final_df['city'].isin(eligible_cities)]

# %%
X = final_df.drop(columns=['match_id','runs_x','runs_y'])
y = final_df['runs_y']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_test

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))

# %%
teams
